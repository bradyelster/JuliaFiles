# %%
using Plots, Printf, LaTeXStrings, DelimitedFiles, LinearAlgebra, CSV, DataFrames

# %%
# Read CSV file
nstx = CSV.read("vp_nstx_midplane.txt", DataFrame)  # Creates a DataFrame

# Extract first 3 columns into variables
Rn = nstx[:, 1]  # First column
Zn = nstx[:, 2]  # Second column
vpn = nstx[:, 3];  # Third column

# %%
theme(:dao)
plot(Rn, vpn, lw=4,
    xlabel=L"$R$ [m]",
    ylabel=L"$v_{\theta}$ [m/s]",
    # xlims=(0,360),
    title="Poloidal Speed (Midplane)",
    legend=:false,
    titlefontsize=20,
    tickfontsize=12,
    legendfontsize=15,
    yguidefontsize=15,
    xguidefontsize=15,
    left_margin=2.5*Plots.mm, 
    dpi = 300
    )
# savefig("NSTX_vp_midplane.png")

# %%
# Read CSV file
d3d = CSV.read("vp_d3d_midplane.txt", DataFrame)  # Creates a DataFrame

# Extract first 3 columns into variables
Rd = d3d[:, 1]  # First column
Zd = d3d[:, 2]  # Second column
vpd = d3d[:, 3];  # Third column

# %%
plot(Rd, vpd, lw=4,
    xlabel=L"$R$ [m]",
    ylabel=L"$v_{\theta}$ [m/s]",
    # xlims=(0,360),
    title="Poloidal Speed (Midplane)",
    legend=:false,
    titlefontsize=20,
    tickfontsize=12,
    legendfontsize=15,
    yguidefontsize=15,
    xguidefontsize=15,
    left_margin=2.5*Plots.mm, 
    dpi = 300
    )
# savefig("D3D_vp_midplane.png")
