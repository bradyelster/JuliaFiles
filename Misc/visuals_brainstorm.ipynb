# %%
using Plots, LaTeXStrings

# %%
x = LinRange(-2π, 2π, 1000)
y = LinRange(-2π, 2π, 1000)

plot(x, cos.(y), ylabel=L"$\cos(y)$", xlabel=L"$x$")

# %%
plot!(tanh.(x), x, ylabel=L"$x$", xlabel=L"$\tanh(x)$")
