# %% [markdown]
# ### Complex Analysis in Julia
# ___
# - This notebook is for visualizing complex-valued functions!
# - I will show some simple calculations with complex numbers as well

# %%
using Plots, LaTeXStrings, Printf, Colors, ComplexPlots;

# %%
# zplot(z -> (z^3 - 1) / (3im - z)^2)
default(aspect_ratio=1)
zplot(z -> z^2, [-1,1], [-1,1])
