# %%
using ModelingToolkit, OrdinaryDiffEq
using BoundaryValueDiffEq, LinearAlgebra, Plots
using ModelingToolkit: t_nounits as t, D_nounits as D

# %%
@constants begin
    g = 9.81
    L = 1
end
@variables begin
    x(t)
    vx(t)
    y(t)
    vy(t)
    T(t)
end

eqs = [D(x) ~ vx,
    D(vx) ~ T * x,
    D(y) ~ vy,
    D(vy) ~ T * y - g,
    x^2 + y^2 - L^2 ~ 0];

# %%
@named model = System(eqs, t)
# Out:
# Model model:
# Equations (5):
#   5 standard: see equations(model)
# Unknowns (5): see unknowns(model)
#   x(t)
#   vx(t)
#   y(t)
#   vy(t)
#   T(t)
# Parameters (2): see parameters(model)
#   L [defaults to 1]
#   g [defaults to 9.81]

# %%
calculate_jacobian(model)
# Out:
# 5×5 Matrix{Num}:
#       0  1       0  0     0
#    T(t)  0       0  0  x(t)
#       0  0       0  1     0
#       0  0    T(t)  0  y(t)
#  -2x(t)  0  -2y(t)  0     0

# %%
ModelingToolkit.calculate_constraint_jacobian(model)
# Out:
# 0×5 Matrix{Num}

# %%
pendulum_sys = mtkcompile(dae_index_lowering(model))
# Out:
# Model model:
# Equations (5):
#   5 standard: see equations(model)
# Unknowns (5): see unknowns(model)
#   T(t)
#   y(t)
#   x(t)
#   vy(t)
#   vx(t)
# Parameters (2): see parameters(model)
#   L [defaults to 1]
#   g [defaults to 9.81]

# %%
ModelingToolkit.calculate_constraint_jacobian(pendulum_sys)
# Out:
# 0×5 Matrix{Num}

# %%
@mtkmodel PENTEST begin
    @constants begin
        g = 9.81
        L = 1
    end
    @variables begin
        x(t)
        vx(t)
        y(t)
        vy(t)
        T(t)
    end

    @equations begin
        D(x) ~ vx
        D(vx) ~ T * x
        D(y) ~ vy
        D(vy) ~ T * y - g
        x^2 + y^2 - L^2 ~ 0
    end
end

@mtkcompile sys = PENTEST()
# Out:
# Model sys:
# Equations (5):
#   5 standard: see equations(sys)
# Unknowns (5): see unknowns(sys)
#   xˍt(t)
#   y(t)
#   x(t)
#   vy(t)
#   T(t)
# Parameters (2): see parameters(sys)
#   L [defaults to 1]
#   g [defaults to 9.81]
# Observed (4): see observed(sys)

# %%
ModelingToolkit.calculate_constraint_jacobian(sys)
# Out:
# 0×5 Matrix{Num}
